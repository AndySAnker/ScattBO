# %%
import matplotlib.pyplot as plt
import numpy as np

def my_plot_convergence(result):
    """
    Plot the convergence of the minimum found vs number of calls.

    Parameters:
    result: The result object returned by the optimizer.

    Returns:
    A matplotlib figure.
    """
    # Extract function values from the result
    func_vals = result.func_vals

    # Compute the minimum function value found at each step
    min_func_vals = np.minimum.accumulate(func_vals)

    # Create a new figure
    fig, ax = plt.subplots()

    # Plot the minimum function value found at each step
    ax.plot(min_func_vals, 'bo-')

    # Set the labels and title
    ax.set_xlabel('Number of calls $n$')
    ax.set_ylabel('Minimum function value after $n$ calls')
    ax.set_title('Convergence plot')

    return fig

my_plot_convergence(res)
plt.show()
